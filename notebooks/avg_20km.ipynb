# %%
# %load_ext autoreload
# %autoreload 2
import sys
# instead of creating a package using setup.py or building from a docker/singularity file,
# import the sister directory of src code to be called on in notebook.
# This keeps the notebook free from code to only hold visualizations and is easier to test
# It also helps keep the state of variables clean such that cells aren't run out of order with a mysterious state
sys.path.append("..")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src import most_recent_mesonet_data
from src import most_recent_mesonet_time
from src import landtype_describe
from src.plotting_scripts import landtype
import os
import pandas as pd

# %%
# This will return the most recent data avail on mesonet 
# this is my file path
ny_mesonet_data_path = '/home/aevans/nysm/archive/nysm/netcdf/proc'
ok_mesonet_data_path = '/home/aevans/landtype/geoinfo.csv'

# %%
# create a dataframe of mesonet data ny
ny_df = most_recent_mesonet_data.current_time_mesonet_df(ny_mesonet_data_path)
ny_df = most_recent_mesonet_time.most_recent_time(ny_df, ny_mesonet_data_path)
ny_df
# Out:
#        index station             time_5M        lat        lon        elev  \
# 244      244    ADDI 2023-01-25 20:20:00  42.040359 -77.237259  507.614014
# 532      532    ANDE 2023-01-25 20:20:00  42.182270 -74.801392  518.281982
# 820      820    BATA 2023-01-25 20:20:00  43.019939 -78.135658  276.119995
# 1108    1108    BEAC 2023-01-25 20:20:00  41.528751 -73.945267   90.159798
# 1396    1396    BELD 2023-01-25 20:20:00  42.223221 -75.668518  470.369995
# ...      ...     ...                 ...        ...        ...         ...
# 35092  35092    WFMB 2023-01-25 20:20:00  44.393234 -73.858826  614.598999
# 35380  35380    WGAT 2023-01-25 20:20:00  43.532410 -75.158600  442.966003
# 35668  35668    WHIT 2023-01-25 20:20:00  43.485073 -73.423073   36.563801
# 35956  35956    WOLC 2023-01-25 20:20:00  43.228680 -76.842613  121.219002
# 36244  36244    YORK 2023-01-25 20:20:00  42.855042 -77.847763  177.942001
#
#            tair      ta9m      tslo       relh  ...  ts05      ts25  ts50  \
# 244   -0.549379 -0.417198 -0.530010  87.838348  ...   1.4  2.400000  3.10
# 532   -2.246521 -2.415372 -2.312704  94.607658  ...   2.3  2.800000  3.48
# 820   -1.584557 -1.551552 -1.768250  95.871712  ...   1.3  2.200000  3.30
# 1108   0.378058  0.033470  0.235776  96.958572  ...   3.1  4.099999  4.30
# 1396  -2.213630 -2.200496 -2.173227  89.609337  ...   2.1  2.300000  2.90
# ...         ...       ...       ...        ...  ...   ...       ...   ...
# 35092 -6.762671 -7.011311 -6.771421  94.587502  ...   0.6  1.400000  2.10
# 35380 -3.391066 -3.457011 -3.355189  93.531593  ...   0.2  0.600000  1.30
# 35668 -2.806006 -3.038294 -2.829500  90.498894  ...   0.2  1.200000  2.60
# 35956       NaN       NaN       NaN        NaN  ...   NaN       NaN   NaN
# 36244  1.027113  0.858815  0.654551  80.663483  ...   1.3  2.220000  3.30
#
#         sm05   sm25   sm50  frozen05  frozen25  frozen50  snow_depth
# 244    0.580  0.440  0.429       0.0       0.0       0.0    0.127709
# 532    0.283  0.175  0.168       0.0       0.0       0.0    0.126281
# 820    0.312  0.260  0.279       0.0       0.0       0.0    0.091313
# 1108   0.380  0.411  0.400       0.0       0.0       0.0    0.005783
# 1396   0.425  0.476  0.402       0.0       0.0       0.0    0.216537
# ...      ...    ...    ...       ...       ...       ...         ...
# 35092  0.251  0.216  0.230       0.0       0.0       0.0    0.218416
# 35380  0.149  0.271  0.091       0.0       0.0       0.0    0.193125
# 35668  0.432  0.514  0.501       0.0       0.0       0.0    0.165651
# 35956    NaN    NaN    NaN       NaN       NaN       NaN         NaN
# 36244  0.289  0.342  0.354       0.0       0.0       0.0    0.057750
#
# [126 rows x 40 columns]

# %%
ny_df_lons = ny_df['lon'].to_list()
ny_df_lats = ny_df['lat'].to_list()

# %%
# create a dataframe of mesonet data ok
ok_df = pd.read_csv(ok_mesonet_data_path)
ok_df
# Out:
#      stnm  stid       name          city  rang cdir      cnty      nlat  \
# 0     110  ACME       Acme  Rush Springs   4.0  WNW     Grady  34.80833
# 1       1  ADAX        Ada           Ada   2.0  NNE  Pontotoc  34.79851
# 2       2  ALTU      Altus         Altus   3.0    S   Jackson  34.58722
# 3     116  ALV2       Alva          Alva   7.2  SSW     Woods  36.70823
# 4       3  ALVA       Alva          Alva   2.0    S     Woods  36.77970
# ..    ...   ...        ...           ...   ...  ...       ...       ...
# 139   105  WILB  Wilburton     Wilburton   2.0   SW   Latimer  34.90092
# 140   106  WIST     Wister        Wister   3.0  ENE   LeFlore  34.98426
# 141   107  WOOD   Woodward      Woodward   2.0  WSW  Woodward  36.42329
# 142   108  WYNO     Wynona        Wynona   2.0    S     Osage  36.51806
# 143   142  YUKO      Yukon         Yukon   2.0    N  Canadian  35.55671
#
#          elon  elev  ...      A75     N75  BULK75  GRAV75  SAND75  SILT75  \
# 0   -98.02325   397  ...    0.178    1.32    1.68     0.0    53.2    24.1
# 1   -96.66909   295  ...    0.053    1.20    1.86     0.0    43.6    26.6
# 2   -99.33808   416  ...    0.059    1.16    1.73     0.0    15.0    40.9
# 3   -98.70974   439  ... -999.000 -999.00 -999.00  -999.0  -999.0  -999.0
# 4   -98.67170   450  ... -999.000 -999.00 -999.00  -999.0  -999.0  -999.0
# ..        ...   ...  ...      ...     ...     ...     ...     ...     ...
# 139 -95.34805   199  ...    0.189    1.21    1.37     0.0     8.7    27.4
# 140 -94.68778   143  ...    0.096    1.16    1.44     0.0     4.4    24.9
# 141 -99.41682   625  ...    0.270    1.47    1.33     0.0    42.6    31.9
# 142 -96.34222   269  ...    0.079    1.23    1.69     0.0     9.8    37.2
# 143 -97.75538   407  ...    0.176    1.34    1.65     0.0    67.3    17.5
#
#      CLAY75           TEXT75      datc      datd
# 0      22.8  Sandy Clay Loam  19940101  20991231
# 1      29.8        Clay Loam  19940101  20991231
# 2      44.1       Silty Clay  19940101  20991231
# 3    -999.0             -999  19981217  20991231
# 4    -999.0             -999  19940101  19981216
# ..      ...              ...       ...       ...
# 139    63.9             Clay  19940101  20991231
# 140    70.8             Clay  19940101  20991231
# 141    25.5             Loam  19940101  20991231
# 142    53.0             Clay  19940101  20991231
# 143    15.3       Sandy Loam  20180618  20991231
#
# [144 rows x 58 columns]

# %%
ok_df_lons = ok_df['elon'].to_list()
ok_df_lats = ok_df['nlat'].to_list()

# %% [markdown]
# develop way to add modes

# %%
csv_path = '/home/aevans/landtype/data/buffer_20_km/'

# %%
# these are my csvs for the landtype buffers in the nysm 
all_files = os.listdir(csv_path)    
csv_files = list(filter(lambda f: f.endswith('.csv'), all_files))
csv_files
# Out:
# ['avg_lulc_ok_20.csv', 'avg_lulc_ny_20.csv']

# %%
station_list_ny = ny_df['station'].to_list()
station_list_ny
# Out:
# ['ADDI',
#  'ANDE',
#  'BATA',
#  'BEAC',
#  'BELD',
#  'BELL',
#  'BELM',
#  'BERK',
#  'BING',
#  'BKLN',
#  'BRAN',
#  'BREW',
#  'BROC',
#  'BRON',
#  'BROO',
#  'BSPA',
#  'BUFF',
#  'BURD',
#  'BURT',
#  'CAMD',
#  'CAPE',
#  'CHAZ',
#  'CHES',
#  'CINC',
#  'CLAR',
#  'CLIF',
#  'CLYM',
#  'COBL',
#  'COHO',
#  'COLD',
#  'COPA',
#  'COPE',
#  'CROG',
#  'CSQR',
#  'DELE',
#  'DEPO',
#  'DOVE',
#  'DUAN',
#  'EAUR',
#  'EDIN',
#  'EDWA',
#  'ELDR',
#  'ELLE',
#  'ELMI',
#  'ESSX',
#  'FAYE',
#  'FRED',
#  'GABR',
#  'GFAL',
#  'GFLD',
#  'GROT',
#  'GROV',
#  'HAMM',
#  'HARP',
#  'HARR',
#  'HART',
#  'HERK',
#  'HFAL',
#  'ILAK',
#  'JOHN',
#  'JORD',
#  'KIND',
#  'LAUR',
#  'LOUI',
#  'MALO',
#  'MANH',
#  'MEDI',
#  'MEDU',
#  'MORR',
#  'NBRA',
#  'NEWC',
#  'NHUD',
#  'OLDF',
#  'OLEA',
#  'ONTA',
#  'OPPE',
#  'OSCE',
#  'OSWE',
#  'OTIS',
#  'OWEG',
#  'PENN',
#  'PHIL',
#  'PISE',
#  'POTS',
#  'QUEE',
#  'RAND',
#  'RAQU',
#  'REDF',
#  'REDH',
#  'ROXB',
#  'RUSH',
#  'SARA',
#  'SBRI',
#  'SCHA',
#  'SCHO',
#  'SCHU',
#  'SCIP',
#  'SHER',
#  'SOME',
#  'SOUT',
#  'SPRA',
#  'SPRI',
#  'STAT',
#  'STEP',
#  'STON',
#  'SUFF',
#  'TANN',
#  'TICO',
#  'TULL',
#  'TUPP',
#  'TYRO',
#  'VOOR',
#  'WALL',
#  'WALT',
#  'WANT',
#  'WARS',
#  'WARW',
#  'WATE',
#  'WBOU',
#  'WELL',
#  'WEST',
#  'WFMB',
#  'WGAT',
#  'WHIT',
#  'WOLC',
#  'YORK']

# %%
# # first mode
# count1_list = [468368]
# class_name1_list = ['Deciduous Forest']
# value1_list = [41]

# # second mode
# count2_list = [357134]
# class_name2_list = ['Pasture/Hay']
# value2_list = [81]

# #third mode
# count3_list = [316094]
# class_name3_list = ['Mixed Forest']
# value3_list = [43]

# %%
# for i in range(2,127):
#     df = pd.read_csv(f'/home/aevans/landtype/data/buffer_20_km/extract_csv_nysm/{i}_csv.csv')
#     the_mode = df.sort_values(by=['Count'], ascending=False) 
#     #first mode
#     first_mode = the_mode.iloc[0]
#     count1 = first_mode['Count'].tolist()
#     class_name1 = first_mode['ClassName']
#     value1 = first_mode['Value'].tolist()
#     count1_list.append(count1)
#     class_name1_list.append(class_name1)
#     value1_list.append(value1)
#     #second mode
#     second_mode = the_mode.iloc[1]
#     count2 = second_mode['Count'].tolist()
#     class_name2 = second_mode['ClassName']
#     value2 = second_mode['Value'].tolist()
#     count2_list.append(count2)
#     class_name2_list.append(class_name2)
#     value2_list.append(value2)
#     #third mode
#     third_mode = the_mode.iloc[2]
#     count3 = third_mode['Count'].tolist()
#     class_name3 = third_mode['ClassName']
#     value3 = third_mode['Value'].tolist()
#     count3_list.append(count3)
#     class_name3_list.append(class_name3)
#     value3_list.append(value3)

# %%
# avg_lulc_ny_20_df = pd.DataFrame()
# avg_lulc_ny_20_df['station'] = station_list_ny
# #first mode
# avg_lulc_ny_20_df['firstmode_count'] = count1_list
# avg_lulc_ny_20_df['firstmode_class'] = class_name1_list
# avg_lulc_ny_20_df['firstmode_val'] = value1_list
# # second mode
# avg_lulc_ny_20_df['secondmode_count'] = count2_list
# avg_lulc_ny_20_df['secondmode_class'] = class_name2_list
# avg_lulc_ny_20_df['secondmode_val'] = value2_list
# #third mode
# avg_lulc_ny_20_df['thirdmode_count'] = count3_list
# avg_lulc_ny_20_df['thirdmode_class'] = class_name3_list
# avg_lulc_ny_20_df['thirdmode_val'] = value3_list
# avg_lulc_ny_20_df.to_csv('/home/aevans/landtype/data/buffer_20_km/avg_lulc_ny_20.csv')

# %% [markdown]
# # Oklahoma

# %%
csv_path = '/home/aevans/landtype/data/buffer_20_km/extract_csv_oksm/'

# %%
# these are my csvs for the landtype buffers in the nysm 
all_files = os.listdir(csv_path)    
csv_files = list(filter(lambda f: f.endswith('.csv'), all_files))
csv_files
# Out:
# ['69_csv.csv',
#  '89_csv.csv',
#  '59_csv.csv',
#  '118_csv.csv',
#  '47_csv.csv',
#  '138_csv.csv',
#  '119_csv.csv',
#  '11_csv.csv',
#  '60_csv.csv',
#  '122_csv.csv',
#  '112_csv.csv',
#  '49_csv.csv',
#  '64_csv.csv',
#  '137_csv.csv',
#  '74_csv.csv',
#  '135_csv.csv',
#  '32_csv.csv',
#  '8_csv.csv',
#  '88_csv.csv',
#  '77_csv.csv',
#  '97_csv.csv',
#  '17_csv.csv',
#  '51_csv.csv',
#  '46_csv.csv',
#  '75_csv.csv',
#  '6_csv.csv',
#  '80_csv.csv',
#  '40_csv.csv',
#  '12_csv.csv',
#  '99_csv.csv',
#  '58_csv.csv',
#  '45_csv.csv',
#  '2_csv.csv',
#  '7_csv.csv',
#  '19_csv.csv',
#  '121_csv.csv',
#  '83_csv.csv',
#  '76_csv.csv',
#  '38_csv.csv',
#  '81_csv.csv',
#  '27_csv.csv',
#  '42_csv.csv',
#  '96_csv.csv',
#  '123_csv.csv',
#  '30_csv.csv',
#  '94_csv.csv',
#  '78_csv.csv',
#  '126_csv.csv',
#  '50_csv.csv',
#  '24_csv.csv',
#  '139_csv.csv',
#  '144_csv.csv',
#  '130_csv.csv',
#  '43_csv.csv',
#  '21_csv.csv',
#  '98_csv.csv',
#  '15_csv.csv',
#  '86_csv.csv',
#  '41_csv.csv',
#  '82_csv.csv',
#  '79_csv.csv',
#  '73_csv.csv',
#  '31_csv.csv',
#  '13_csv.csv',
#  '18_csv.csv',
#  '140_csv.csv',
#  '84_csv.csv',
#  '29_csv.csv',
#  '63_csv.csv',
#  '48_csv.csv',
#  '44_csv.csv',
#  '125_csv.csv',
#  '136_csv.csv',
#  '124_csv.csv',
#  '37_csv.csv',
#  '134_csv.csv',
#  '141_csv.csv',
#  '102_csv.csv',
#  '22_csv.csv',
#  '117_csv.csv',
#  '14_csv.csv',
#  '26_csv.csv',
#  '9_csv.csv',
#  '25_csv.csv',
#  '20_csv.csv',
#  '129_csv.csv',
#  '120_csv.csv',
#  '95_csv.csv',
#  '70_csv.csv',
#  '34_csv.csv',
#  '33_csv.csv',
#  '35_csv.csv',
#  '10_csv.csv',
#  '5_csv.csv',
#  '68_csv.csv',
#  '61_csv.csv',
#  '55_csv.csv',
#  '54_csv.csv',
#  '65_csv.csv',
#  '72_csv.csv',
#  '16_csv.csv',
#  '109_csv.csv',
#  '142_csv.csv',
#  '111_csv.csv',
#  '52_csv.csv',
#  '66_csv.csv',
#  '28_csv.csv',
#  '36_csv.csv',
#  '1_csv.csv',
#  '128_csv.csv',
#  '4_csv.csv',
#  '62_csv.csv',
#  '104_csv.csv',
#  '114_csv.csv',
#  '132_csv.csv',
#  '100_csv.csv',
#  '116_csv.csv',
#  '101_csv.csv',
#  '53_csv.csv',
#  '56_csv.csv',
#  '57_csv.csv',
#  '143_csv.csv',
#  '115_csv.csv',
#  '113_csv.csv',
#  '90_csv.csv',
#  '39_csv.csv',
#  '87_csv.csv',
#  '71_csv.csv',
#  '105_csv.csv',
#  '85_csv.csv',
#  '107_csv.csv',
#  '127_csv.csv',
#  '108_csv.csv',
#  '23_csv.csv',
#  '91_csv.csv',
#  '67_csv.csv',
#  '131_csv.csv',
#  '110_csv.csv',
#  '93_csv.csv',
#  '103_csv.csv',
#  '3_csv.csv',
#  '92_csv.csv',
#  '133_csv.csv',
#  '106_csv.csv']

# %%
station_list_ok = ok_df['stid'].to_list()
len(station_list_ok)
# Out:
# 144

# %%
# first mode
count1_list_ok = [963913]
class_name1_list_ok = ['Grassland/Herbaceous']
value1_list_ok = [71]

# second mode
count2_list_ok = [197238]
class_name2_list_ok = ['Deciduous Forest']
value2_list_ok = [41]

#third mode
count3_list_ok = [124650]
class_name3_list_ok = ['Cultivated Crops']
value3_list_ok = [82]

# %%
# for i in range(2,145):
#     df = pd.read_csv(f'/home/aevans/landtype/data/buffer_20_km/extract_csv_oksm/{i}_csv.csv')
#     the_mode = df.sort_values(by=['Count'], ascending=False) 
#     #first mode
#     first_mode = the_mode.iloc[0]
#     count1 = first_mode['Count'].tolist()
#     class_name1 = first_mode['ClassName']
#     value1 = first_mode['Value'].tolist()
#     count1_list_ok.append(count1)
#     class_name1_list_ok.append(class_name1)
#     value1_list_ok.append(value1)
#     #second mode
#     second_mode = the_mode.iloc[1]
#     count2 = second_mode['Count'].tolist()
#     class_name2 = second_mode['ClassName']
#     value2 = second_mode['Value'].tolist()
#     count2_list_ok.append(count2)
#     class_name2_list_ok.append(class_name2)
#     value2_list_ok.append(value2)
#     #third mode
#     third_mode = the_mode.iloc[2]
#     count3 = third_mode['Count'].tolist()
#     class_name3 = third_mode['ClassName']
#     value3 = third_mode['Value'].tolist()
#     count3_list_ok.append(count3)
#     class_name3_list_ok.append(class_name3)
#     value3_list_ok.append(value3)

# %%
# avg_lulc_ok_20_df = pd.DataFrame()
# avg_lulc_ok_20_df['station'] = station_list_ok
# #first mode
# avg_lulc_ok_20_df['firstmode_count'] = count1_list_ok
# avg_lulc_ok_20_df['firstmode_class'] = class_name1_list_ok
# avg_lulc_ok_20_df['firstmode_val'] = value1_list_ok
# # second mode
# avg_lulc_ok_20_df['secondmode_count'] = count2_list_ok
# avg_lulc_ok_20_df['secondmode_class'] = class_name2_list_ok
# avg_lulc_ok_20_df['secondmode_val'] = value2_list_ok
# #third mode
# avg_lulc_ok_20_df['thirdmode_count'] = count3_list_ok
# avg_lulc_ok_20_df['thirdmode_class'] = class_name3_list_ok
# avg_lulc_ok_20_df['thirdmode_val'] = value3_list_ok
# avg_lulc_ok_20_df.to_csv('/home/aevans/landtype/data/buffer_20_km/avg_lulc_ok_20.csv')

# %%
import matplotlib.pyplot as plt 
import pandas as pd
import cartopy.crs as crs
import cartopy.feature as cfeature
import numpy as np
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches
from matplotlib import colors

LEG_STR = ['No Data','Open Water','Perennial Ice/Snow',
    'Developed, Open Space','Developed, Low Intensity', 'Developed, Medium Intensity','Developed High Intensity',
    'Barren Land (Rock/Sand/Clay)',
    'Deciduous Forest','Evergreen Forest','Mixed Forest', 'Forest/Shrub',
    'Dwarf Scrub','Shrub/Scrub',
    'Grassland/Herbaceous','Sedge/Herbaceous','Lichens','Moss',
    'Pasture/Hay','Cultivated Crops',
    'Woody Wetlands','Emergent Herbaceous Wetlands']
COLORS = ['black', 'blue', 'white', 'coral', 'pink', 'red', 'magenta', 'gray', 'lime', 'forestgreen', 'green', 'olive', 'brown', 'slategray', 'darkorchid','plum', 'indigo', 'purple', 'yellow', 'gold', 'orange', 'cyan']


def create_cmap()->ListedColormap:
    """
    this creates the landtype colormap

    Returns:
        cmap (ListedColorMap)
    """

    legend = np.array([0,11,12,21,22,23,24,31,41,42,43,45,51,52,71,72,73,74,81,82,90,95])


    colordict={}
    for x,_ in enumerate(COLORS):
        colordict.update({legend[x] : COLORS[x]})
    return ListedColormap(colordict)


def landtype(df:pd.DataFrame)->None: 
    """
    this plots the landtype for a specified region determined by the imported dataframe

    Args: 
        df (pd.DataFrame): landtype, lat, lon
    """
    cmap = create_cmap()

    projPC = crs.PlateCarree()
    latN = df['lat'].max()
    latS = df['lat'].min()
    lonW = df['lon'].max()
    lonE = df['lon'].min()
    cLat = (latN + latS) / 2
    cLon = (lonW + lonE) / 2
    projLcc = crs.LambertConformal(central_longitude=cLon, central_latitude=cLat)

    fig, ax = plt.subplots(figsize=(12,9), subplot_kw={'projection': crs.PlateCarree()})
    ax.legend()
    ax.set_extent([lonW, lonE, latS, latN], crs=projPC)
    ax.add_feature(cfeature.LAND)
    ax.add_feature(cfeature.COASTLINE)
    ax.add_feature(cfeature.BORDERS, linestyle='--');
    ax.add_feature(cfeature.LAKES, alpha=0.5)
    ax.add_feature(cfeature.STATES)
    ax.xticklabels_top = False
    ax.ylabels_right = False
    ax.gridlines(crs=crs.PlateCarree(), draw_labels=True,
                    linewidth=2, color='black', alpha=0.5, linestyle='--')

    plt.scatter(df['lon'], df['lat'], c=df['color'], cmap = cmap, transform=crs.PlateCarree(), zorder=5)

    #legend 
    patches = []
    for i,_ in enumerate(COLORS):
            patch = mpatches.Patch(color=COLORS[i], label=LEG_STR[i])
            patches.append(patch)
            


    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0,handles=patches)

# %%
avg_lulc_ny_20_df = pd.read_csv('/home/aevans/landtype/data/buffer_20_km/avg_lulc_ny_20.csv')
avg_lulc_ok_20_df = pd.read_csv('/home/aevans/landtype/data/buffer_20_km/avg_lulc_ok_20.csv')

# %%
colors = ['black', 'blue', 'white', 'coral', 'pink', 'red', 'magenta', 'gray', 'lime', 'forestgreen', 'green', 'olive', 'brown', 'slategray', 'darkorchid','plum', 'indigo', 'purple', 'yellow', 'gold', 'orange', 'cyan']
legend = np.array([0,11,12,21,22,23,24,31,41,42,43,45,51,52,71,72,73,74,81,82,90,95])
leg_str = ['No Data','Open Water','Perennial Ice/Snow',
'Developed, Open Space','Developed, Low Intensity', 'Developed, Medium Intensity','Developed High Intensity',
'Barren Land (Rock/Sand/Clay)',
'Deciduous Forest','Evergreen Forest','Mixed Forest', 'Forest/Shrub',
'Dwarf Scrub','Shrub/Scrub',
'Grassland/Herbaceous','Sedge/Herbaceous','Lichens','Moss',
'Pasture/Hay','Cultivated Crops',
'Woody Wetlands','Emergent Herbaceous Wetlands']

descripdict={}
colordict={}

for x,_ in enumerate(colors):
    descripdict.update({legend[x] : leg_str[x]})
    colordict.update({legend[x] : colors[x]})


avg_lulc_ny_20_df['color'] = avg_lulc_ny_20_df['firstmode_val'].map(colordict)
avg_lulc_ny_20_df['lon'] = ny_df_lons
avg_lulc_ny_20_df['lat'] = ny_df_lats

# %%
landtype(avg_lulc_ny_20_df)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
colors = ['black', 'blue', 'white', 'coral', 'pink', 'red', 'magenta', 'gray', 'lime', 'forestgreen', 'green', 'olive', 'brown', 'slategray', 'darkorchid','plum', 'indigo', 'purple', 'yellow', 'gold', 'orange', 'cyan']
legend = np.array([0,11,12,21,22,23,24,31,41,42,43,45,51,52,71,72,73,74,81,82,90,95])
leg_str = ['No Data','Open Water','Perennial Ice/Snow',
'Developed, Open Space','Developed, Low Intensity', 'Developed, Medium Intensity','Developed High Intensity',
'Barren Land (Rock/Sand/Clay)',
'Deciduous Forest','Evergreen Forest','Mixed Forest', 'Forest/Shrub',
'Dwarf Scrub','Shrub/Scrub',
'Grassland/Herbaceous','Sedge/Herbaceous','Lichens','Moss',
'Pasture/Hay','Cultivated Crops',
'Woody Wetlands','Emergent Herbaceous Wetlands']

descripdict={}
colordict={}

for x,_ in enumerate(colors):
    descripdict.update({legend[x] : leg_str[x]})
    colordict.update({legend[x] : colors[x]})


avg_lulc_ok_20_df['color'] = avg_lulc_ok_20_df['firstmode_val'].map(colordict)
avg_lulc_ok_20_df['lon'] = ok_df_lons
avg_lulc_ok_20_df['lat'] = ok_df_lats

# %%
landtype(avg_lulc_ok_20_df)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
avg_lulc_ny_20_df
# Out:
#      Unnamed: 0 station  firstmode_count   firstmode_class  firstmode_val  \
# 0             0    ADDI         468368.0  Deciduous Forest             41
# 1             1    ANDE         857853.0  Deciduous Forest             41
# 2             2    BATA         671178.0  Cultivated Crops             82
# 3             3    BEAC         666443.0  Deciduous Forest             41
# 4             4    BELD         449674.0  Deciduous Forest             41
# ..          ...     ...              ...               ...            ...
# 121         121    WFMB         504995.0  Deciduous Forest             41
# 122         122    WGAT         720014.0  Deciduous Forest             41
# 123         123    WHIT         416387.0  Deciduous Forest             41
# 124         124    WOLC         363307.0        Open Water             11
# 125         125    YORK         730716.0  Cultivated Crops             82
#
#      secondmode_count      secondmode_class  secondmode_val  thirdmode_count  \
# 0            357134.0           Pasture/Hay              81         316094.0
# 1            206134.0          Mixed Forest              43         157650.0
# 2            252276.0        Woody Wetlands              90         171144.0
# 3            142805.0  Developed Open Space              21         121994.0
# 4            414229.0          Mixed Forest              43         265253.0
# ..                ...                   ...             ...              ...
# 121          470051.0      Evergreen Forest              42         202824.0
# 122          197224.0      Evergreen Forest              42         181113.0
# 123          269191.0      Evergreen Forest              42         232517.0
# 124          307631.0      Deciduous Forest              41         298571.0
# 125          227579.0      Deciduous Forest              41         151092.0
#
#       thirdmode_class  thirdmode_val color        lon        lat
# 0        Mixed Forest             43  lime -77.237259  42.040359
# 1         Pasture/Hay             81  lime -74.801392  42.182270
# 2    Deciduous Forest             41  gold -78.135658  43.019939
# 3      Woody Wetlands             90  lime -73.945267  41.528751
# 4         Pasture/Hay             81  lime -75.668518  42.223221
# ..                ...            ...   ...        ...        ...
# 121      Mixed Forest             43  lime -73.858826  44.393234
# 122    Woody Wetlands             90  lime -75.158600  43.532410
# 123       Pasture/Hay             81  lime -73.423073  43.485073
# 124  Cultivated Crops             82  blue -76.842613  43.228680
# 125       Pasture/Hay             81  gold -77.847763  42.855042
#
# [126 rows x 14 columns]

# %%
avg_lulc_ny_20_df['firstmode_class'].value_counts()
# Out:
# Deciduous Forest            86
# Open Water                  15
# Cultivated Crops            11
# Pasture/Hay                  4
# Developed High Intensity     3
# Woody Wetlands               2
# Evergreen Forest             2
# Mixed Forest                 2
# Developed Low Intensity      1
# Name: firstmode_class, dtype: int64

# %%
avg_lulc_ok_20_df['firstmode_class'].value_counts()
# Out:
# Grassland/Herbaceous          66
# Pasture/Hay                   27
# Deciduous Forest              21
# Cultivated Crops              20
# Evergreen Forest               5
# Mixed Forest                   2
# Shrub/Scrub                    2
# Developed Medium Intensity     1
# Name: firstmode_class, dtype: int64

# %%
def format_df(df):
    colors = ['black', 'blue', 'white', 'coral', 'pink', 'red', 'magenta', 'gray', 'lime', 'forestgreen', 'green', 'olive', 'brown', 'slategray', 'darkorchid','plum', 'indigo', 'purple', 'yellow', 'gold', 'orange', 'cyan']
    legend = np.array([0,11,12,21,22,23,24,31,41,42,43,45,51,52,71,72,73,74,81,82,90,95])
    leg_str = ['No Data','Open Water','Perennial Ice/Snow',
    'Developed, Open Space','Developed, Low Intensity', 'Developed, Medium Intensity','Developed High Intensity',
    'Barren Land (Rock/Sand/Clay)',
    'Deciduous Forest','Evergreen Forest','Mixed Forest', 'Forest/Shrub',
    'Dwarf Scrub','Shrub/Scrub',
    'Grassland/Herbaceous','Sedge/Herbaceous','Lichens','Moss',
    'Pasture/Hay','Cultivated Crops',
    'Woody Wetlands','Emergent Herbaceous Wetlands']

    descripdict={}
    colordict={}

    for x,_ in enumerate(colors):
        descripdict.update({legend[x] : leg_str[x]})
        colordict.update({legend[x] : colors[x]})


    df['color'] = df['firstmode_val'].map(colordict)

    total = df['firstmode_count'] + df['secondmode_count'] + df['thirdmode_count']
    df['divide'] = (df['firstmode_count'] / total) * 100

def plurality_plot(df):

    colors = ['black', 'blue', 'white', 'coral', 'pink', 'red', 'magenta', 'gray', 'lime', 'forestgreen', 'green', 'olive', 'brown', 'slategray', 'darkorchid','plum', 'indigo', 'purple', 'yellow', 'gold', 'orange', 'cyan']
    legend = np.array([0,11,12,21,22,23,24,31,41,42,43,45,51,52,71,72,73,74,81,82,90,95])
    leg_str = ['No Data','Open Water','Perennial Ice/Snow',
    'Developed, Open Space','Developed, Low Intensity', 'Developed, Medium Intensity','Developed High Intensity',
    'Barren Land (Rock/Sand/Clay)',
    'Deciduous Forest','Evergreen Forest','Mixed Forest', 'Forest/Shrub',
    'Dwarf Scrub','Shrub/Scrub',
    'Grassland/Herbaceous','Sedge/Herbaceous','Lichens','Moss',
    'Pasture/Hay','Cultivated Crops',
    'Woody Wetlands','Emergent Herbaceous Wetlands']
    
              #legend 
    patches = []
    for i,_ in enumerate(colors):
            patch = mpatches.Patch(color=colors[i], label=leg_str[i])
            patches.append(patch)

    fig, ax = plt.subplots()
    df.plot.scatter(x='lon',
                                        y='lat',
                                        c='color',
                                        s='divide',
                                        marker = 'o',
                                        figsize=(9,6),
                                        ax = ax
                                        )
    ax.set_title('Mesonet Site Plurality by Landtype', size=16)
    ax.set_xlabel('Longitude',size=14)
    ax.set_ylabel('Latitude',size=14)
    ax.tick_params(axis='x', labelsize=12)
    ax.tick_params(axis='y', labelsize=12)
    ax.grid()
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0,handles=patches)

def percent_plot(df):
    colors = ['black', 'blue', 'white', 'coral', 'pink', 'red', 'magenta', 'gray', 'lime', 'forestgreen', 'green', 'olive', 'brown', 'slategray', 'darkorchid','plum', 'indigo', 'purple', 'yellow', 'gold', 'orange', 'cyan']
    legend = np.array([0,11,12,21,22,23,24,31,41,42,43,45,51,52,71,72,73,74,81,82,90,95])
    leg_str = ['No Data','Open Water','Perennial Ice/Snow',
    'Developed, Open Space','Developed, Low Intensity', 'Developed, Medium Intensity','Developed High Intensity',
    'Barren Land (Rock/Sand/Clay)',
    'Deciduous Forest','Evergreen Forest','Mixed Forest', 'Forest/Shrub',
    'Dwarf Scrub','Shrub/Scrub',
    'Grassland/Herbaceous','Sedge/Herbaceous','Lichens','Moss',
    'Pasture/Hay','Cultivated Crops',
    'Woody Wetlands','Emergent Herbaceous Wetlands']

                #legend 
    patches = []
    for i,_ in enumerate(colors):
            patch = mpatches.Patch(color=colors[i], label=leg_str[i])
            patches.append(patch)
        
    fig, ax = plt.subplots(figsize=(20,10))
    ax.scatter(df['station'], df['divide'], c=df['color'], s=50)
    for n in df.iterrows():
        ax.annotate(n[1]['station'], (n[1]['station'], n[1]['divide']), fontsize=15)
    ax.grid()
    ax.set_ylabel('Percent of Total', size=20)
    ax.tick_params(labelbottom = False, bottom = False)
    ax.legend(bbox_to_anchor=(1.05, 1), loc='center left', borderaxespad=0,handles=patches)

# %%
format_df(avg_lulc_ok_20_df)
format_df(avg_lulc_ny_20_df)

# %%
plurality_plot(avg_lulc_ny_20_df)

# %%
pluarlity_plot(avg_lulc_ok_20_df)

# %%
percent_plot(avg_lulc_ny_20_df)

# %%
percent_plot(avg_lulc_ok_20_df)
