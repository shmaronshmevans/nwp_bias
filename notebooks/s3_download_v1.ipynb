# %% [markdown]
# ## Questions I have
# - bucket
# - split_loc
# - fh_loc
# - fxx_max
# - z_fill
# - full file_list_len

# %%
import sys
import numpy as np
import s3fs
import argparse
from datetime import datetime, timedelta
import os.path
from pathlib import Path
import time
import glob

from boto3 import client
from botocore import UNSIGNED
from botocore.client import Config

# %% [markdown]
# # Functions

# %%
"""
 download_s3_file 
 downloads the nwp file 

 ARGS: 
 bucket: f string :: 
 ingest_path : fstring  :: file that has been downloaded 
 output_path : fstring :: where you want file stored 

 RETURNS: 

 """


def download_s3_file(bucket, ingest_path, output_path):
    fs = s3fs.S3FileSystem(anon=True, asynchronous=False)

    if fs.exists(f"{bucket}/{ingest_path}"):
        # Download file, will throw FileNotFoundError if non existent
        fs.download(f"{bucket}/{ingest_path}", output_path)
        print(f"✅ downloading {ingest_path} & saving to {output_path}")
    else:
        print(f"‼️ file not found {ingest_path}")


"""
list_s3_files 
returns a list of files that have been downloaded for nwp 

 ARGS: 
 bucket
 model : string :: the model to be downloaded 
 date : fstring :: year-month-day
 init_time : double :: 00
 data_type : string :: file format 

 RETURNS: 
 list :: the files that exist from dowload in a list 

 """


def list_s3_files(bucket, model, date, init_time, data_type):
    conn = client("s3", config=Config(signature_version=UNSIGNED))

    if model == "nam":
        prefix = f"{model}.{date}/"
    elif model == "gfs":
        prefix = f"{model}.{date}/{init_time}/atmos/"
    elif model == "hrrr":
        prefix = f"{model}.{date}/conus/"

    response = conn.list_objects_v2(
        Bucket=bucket, Prefix=f"{prefix}{model}.t{init_time}z.{data_type}"
    )
    files = response.get("Contents")
    if files:
        all_files = [file.get("Key") for file in files]
        existing_files_for_download = [
            file
            for file in all_files
            if f"t{init_time}z.{data_type}" in file
            and not file.endswith("idx")
            and not file.endswith("anl")
        ]
        existing_files_for_download.sort()
        return existing_files_for_download
    else:
        return []


"""
get_avail_files 

 ARGS: 
 s3_bucket
 model : string :: the model to be downloaded 
 year : string :: 0000
 month : string :: 00
 day : string  :: 00
 init_time : double :: 00
 data_type : string :: file format 
 split_loc: 
 fh_loc: 
 fxx_max: 
 zfill: 
 download_dir: fstring :: directory path where you want the  data to be downloaded 

 fname_out: string :: part of datapath name to be saved in your directory 

 fname_end: string :: part of datapath name
 full_filelist_len: 

 RETURNS: 
 the files that exist for dowload 

 """


def get_avail_files(
    s3_bucket,
    model,
    year,
    month,
    day,
    init_time,
    data_type,
    split_loc,
    fh_loc,
    fxx_max,
    zfill,
    download_dir,
    fname_out,
    fname_end,
    full_filelist_len,
):
    ii = 0
    len_files_for_download = [0]
    while True:
        files_for_download = list_s3_files(
            s3_bucket, model, f"{year}{month}{day}", init_time, data_type
        )
        files_for_download = [
            file
            for file in files_for_download
            if int(file.split(".")[split_loc][fh_loc:]) <= fxx_max
        ]
        print(files_for_download)
        len_files_for_download.append(len(files_for_download))
        for file in files_for_download:
            fxx = file.split(".")[split_loc][fh_loc:]
            if not os.path.isdir(download_dir):
                print("making directory: ", download_dir)
                Path(download_dir).mkdir(parents=True, exist_ok=True)
            # check to see if output_path is a directory. if not, create directory
            output_path = f"{download_dir}{fname_out}{str(fxx).zfill(zfill)}{fname_end}"
            if not os.path.exists(output_path):
                # if the file already exists, do not redownload
                download_s3_file(s3_bucket, file, output_path)
                # call the rest of the pipeline here, run_pipeline
                # running cleaning through the pipeline could be the "sleep" period
                print("FXX IS: ", fxx)
            else:
                print(f"file has already been downloaded: {output_path}")

        # STOP WHILE LOOP IF ALL DESIRED FILES HAVE BEEN DOWNLOADED ON OUR SIDE
        if os.path.isdir(download_dir):
            files_downloaded = glob.glob(f"{download_dir}{fname_out}*{fname_end}")
            num_files_downloaded = len(files_downloaded)
            print(num_files_downloaded)
            if num_files_downloaded >= full_filelist_len:
                print("exiting from while loop")
                break

        # if no additional files are available compared to last try but the full_filelist_len has not been reached yet...
        if len_files_for_download[-1] == len_files_for_download[-2]:
            ii += 1
            print("same number of available files as last try. ii=", ii)
            if (
                ii > 10
            ):  # stop waiting for additional file if we have tried 10 separate times
                print("waited too long for new file, exiting while loop")
                break

        # try again in 90 seconds
        print("sleep: ", datetime.now())
        time.sleep(90)

# %% [markdown]
# # Global Variables

# %%
# this is how you want the files to be input for each model
# second component is the file format
data_type_dict = {"gfs": "pgrb2.0p50", "nam": "awphys", "hrrr": "wrfsfc"}

# download request time
init_time = "06"
init_date = datetime(2021, 11, 1)
end_date = datetime(2021, 12, 31)

# %% [markdown]
# # Main

# %%
# main
def main(model, data_type, init_date, init_time):
    month = str(init_date.month).zfill(2)
    print("Month: ", month)
    year = init_date.year
    print("Year", year)
    day = str(init_date.day).zfill(2)

    # where you want the files to download
    download_dir = (
        f"/home/aevans/nwp_bias/data/model_data/{model.upper()}/{year}/{month}/"
    )
    print("Downloand_dir: ", download_dir)

    if model == "nam":
        s3_bucket = f"noaa-{model}-pds"
    else:
        s3_bucket = f"noaa-{model}-bdp-pds"

    if model == "nam":
        fxx_max = 84
        split_loc, fh_loc = -3, -2
        fname_out = f"nam_218_{year}{month}{day}_{init_time}00_"
        fname_end = ".grb2"
        zfill = 3
        full_filelist_len = len(
            np.arange(0, 37, 1).tolist() + np.arange(39, 85, 3).tolist()
        )
    elif model == "gfs":
        fxx_max = 96
        split_loc, fh_loc = -1, 1
        fname_out = f"gfs_4_{year}{month}{day}_{init_time}00_"
        fname_end = ".grb2"
        zfill = 3
        full_filelist_len = len(np.arange(0, 99, 3))
    elif model == "hrrr":
        fxx_max = 18
        split_loc, fh_loc = -2, -2
        fname_out = f"{year}{month}{day}_hrrr.t{init_time}z.wrfsfcf"
        fname_end = ".grib2"
        zfill = 2
        full_filelist_len = len(range(0, 19))

    get_avail_files(
        s3_bucket,
        model,
        year,
        month,
        day,
        init_time,
        data_type,
        split_loc,
        fh_loc,
        fxx_max,
        zfill,
        download_dir,
        fname_out,
        fname_end,
        full_filelist_len,
    )

    print(
        f"full download for {init_time}z initialization of the {model.upper()} complete!"
    )

# %% [markdown]
# # GFS

# %%
# delta2 = timedelta(days=1)
# while init_date < end_date:
#     main("gfs", data_type_dict.get("gfs"), init_date, init_time)
#     init_date += delta2

# %% [markdown]
# # NAM

# %%
delta2 = timedelta(days=1)
while init_date < end_date:
    main("nam", data_type_dict.get("nam"), init_date, init_time)
    init_date += delta2
# Out:
# Month:  11
# Year 2021
# Downloand_dir:  /home/aevans/nwp_bias/data/model_data/NAM/2021/11/
# ['nam.20211101/nam.t06z.awphys00.tm00.grib2', 'nam.20211101/nam.t06z.awphys01.tm00.grib2', 'nam.20211101/nam.t06z.awphys02.tm00.grib2', 'nam.20211101/nam.t06z.awphys03.tm00.grib2', 'nam.20211101/nam.t06z.awphys04.tm00.grib2', 'nam.20211101/nam.t06z.awphys05.tm00.grib2', 'nam.20211101/nam.t06z.awphys06.tm00.grib2', 'nam.20211101/nam.t06z.awphys07.tm00.grib2', 'nam.20211101/nam.t06z.awphys08.tm00.grib2', 'nam.20211101/nam.t06z.awphys09.tm00.grib2', 'nam.20211101/nam.t06z.awphys10.tm00.grib2', 'nam.20211101/nam.t06z.awphys11.tm00.grib2', 'nam.20211101/nam.t06z.awphys12.tm00.grib2', 'nam.20211101/nam.t06z.awphys13.tm00.grib2', 'nam.20211101/nam.t06z.awphys14.tm00.grib2', 'nam.20211101/nam.t06z.awphys15.tm00.grib2', 'nam.20211101/nam.t06z.awphys16.tm00.grib2', 'nam.20211101/nam.t06z.awphys17.tm00.grib2', 'nam.20211101/nam.t06z.awphys18.tm00.grib2', 'nam.20211101/nam.t06z.awphys19.tm00.grib2', 'nam.20211101/nam.t06z.awphys20.tm00.grib2', 'nam.20211101/nam.t06z.awphys21.tm00.grib2', 'nam.20211101/nam.t06z.awphys22.tm00.grib2', 'nam.20211101/nam.t06z.awphys23.tm00.grib2', 'nam.20211101/nam.t06z.awphys24.tm00.grib2', 'nam.20211101/nam.t06z.awphys25.tm00.grib2', 'nam.20211101/nam.t06z.awphys26.tm00.grib2', 'nam.20211101/nam.t06z.awphys27.tm00.grib2', 'nam.20211101/nam.t06z.awphys28.tm00.grib2', 'nam.20211101/nam.t06z.awphys29.tm00.grib2', 'nam.20211101/nam.t06z.awphys30.tm00.grib2', 'nam.20211101/nam.t06z.awphys31.tm00.grib2', 'nam.20211101/nam.t06z.awphys32.tm00.grib2', 'nam.20211101/nam.t06z.awphys33.tm00.grib2', 'nam.20211101/nam.t06z.awphys34.tm00.grib2', 'nam.20211101/nam.t06z.awphys35.tm00.grib2', 'nam.20211101/nam.t06z.awphys36.tm00.grib2', 'nam.20211101/nam.t06z.awphys39.tm00.grib2', 'nam.20211101/nam.t06z.awphys42.tm00.grib2', 'nam.20211101/nam.t06z.awphys45.tm00.grib2', 'nam.20211101/nam.t06z.awphys48.tm00.grib2', 'nam.20211101/nam.t06z.awphys51.tm00.grib2', 'nam.20211101/nam.t06z.awphys54.tm00.grib2', 'nam.20211101/nam.t06z.awphys57.tm00.grib2', 'nam.20211101/nam.t06z.awphys60.tm00.grib2', 'nam.20211101/nam.t06z.awphys63.tm00.grib2', 'nam.20211101/nam.t06z.awphys66.tm00.grib2', 'nam.20211101/nam.t06z.awphys69.tm00.grib2', 'nam.20211101/nam.t06z.awphys72.tm00.grib2', 'nam.20211101/nam.t06z.awphys75.tm00.grib2', 'nam.20211101/nam.t06z.awphys78.tm00.grib2', 'nam.20211101/nam.t06z.awphys81.tm00.grib2', 'nam.20211101/nam.t06z.awphys84.tm00.grib2']
# making directory:  /home/aevans/nwp_bias/data/model_data/NAM/2021/11/
# ✅ downloading nam.20211101/nam.t06z.awphys00.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_000.grb2
# FXX IS:  00
# ✅ downloading nam.20211101/nam.t06z.awphys01.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_001.grb2
# FXX IS:  01
# ✅ downloading nam.20211101/nam.t06z.awphys02.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_002.grb2
# FXX IS:  02
# ✅ downloading nam.20211101/nam.t06z.awphys03.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_003.grb2
# FXX IS:  03
# ✅ downloading nam.20211101/nam.t06z.awphys04.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_004.grb2
# FXX IS:  04
# ✅ downloading nam.20211101/nam.t06z.awphys05.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_005.grb2
# FXX IS:  05
# ✅ downloading nam.20211101/nam.t06z.awphys06.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_006.grb2
# FXX IS:  06
# ✅ downloading nam.20211101/nam.t06z.awphys07.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_007.grb2
# FXX IS:  07
# ✅ downloading nam.20211101/nam.t06z.awphys08.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_008.grb2
# FXX IS:  08
# ✅ downloading nam.20211101/nam.t06z.awphys09.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_009.grb2
# FXX IS:  09
# ✅ downloading nam.20211101/nam.t06z.awphys10.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_010.grb2
# FXX IS:  10
# ✅ downloading nam.20211101/nam.t06z.awphys11.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_011.grb2
# FXX IS:  11
# ✅ downloading nam.20211101/nam.t06z.awphys12.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_012.grb2
# FXX IS:  12
# ✅ downloading nam.20211101/nam.t06z.awphys13.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_013.grb2
# FXX IS:  13
# ✅ downloading nam.20211101/nam.t06z.awphys14.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_014.grb2
# FXX IS:  14
# ✅ downloading nam.20211101/nam.t06z.awphys15.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_015.grb2
# FXX IS:  15
# ✅ downloading nam.20211101/nam.t06z.awphys16.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_016.grb2
# FXX IS:  16
# ✅ downloading nam.20211101/nam.t06z.awphys17.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_017.grb2
# FXX IS:  17
# ✅ downloading nam.20211101/nam.t06z.awphys18.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_018.grb2
# FXX IS:  18
# ✅ downloading nam.20211101/nam.t06z.awphys19.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_019.grb2
# FXX IS:  19
# ✅ downloading nam.20211101/nam.t06z.awphys20.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_020.grb2
# FXX IS:  20
# ✅ downloading nam.20211101/nam.t06z.awphys21.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_021.grb2
# FXX IS:  21
# ✅ downloading nam.20211101/nam.t06z.awphys22.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_022.grb2
# FXX IS:  22
# ✅ downloading nam.20211101/nam.t06z.awphys23.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_023.grb2
# FXX IS:  23
# ✅ downloading nam.20211101/nam.t06z.awphys24.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_024.grb2
# FXX IS:  24
# ✅ downloading nam.20211101/nam.t06z.awphys25.tm00.grib2 & saving to /home/aevans/nwp_bias/data/model_data/NAM/2021/11/nam_218_20211101_0600_025.grb2
# FXX IS:  25
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 delta2 = timedelta(days=1)
#       2 while init_date < end_date:
# ----> 3     main("nam", data_type_dict.get("nam"), init_date, init_time)
#       4     init_date += delta2
#
# Cell In[10], line 44, in main(model, data_type, init_date, init_time)
#      41     zfill = 2
#      42     full_filelist_len = len(range(0, 19))
# ---> 44 get_avail_files(
#      45     s3_bucket,
#      46     model,
#      47     year,
#      48     month,
#      49     day,
#      50     init_time,
#      51     data_type,
#      52     split_loc,
#      53     fh_loc,
#      54     fxx_max,
#      55     zfill,
#      56     download_dir,
#      57     fname_out,
#      58     fname_end,
#      59     full_filelist_len,
#      60 )
#      62 print(
#      63     f"full download for {init_time}z initialization of the {model.upper()} complete!"
#      64 )
#
# Cell In[8], line 139, in get_avail_files(s3_bucket, model, year, month, day, init_time, data_type, split_loc, fh_loc, fxx_max, zfill, download_dir, fname_out, fname_end, full_filelist_len)
#     136 output_path = f"{download_dir}{fname_out}{str(fxx).zfill(zfill)}{fname_end}"
#     137 if not os.path.exists(output_path):
#     138     # if the file already exists, do not redownload
# --> 139     download_s3_file(s3_bucket, file, output_path)
#     140     # call the rest of the pipeline here, run_pipeline
#     141     # running cleaning through the pipeline could be the "sleep" period
#     142     print("FXX IS: ", fxx)
#
# Cell In[8], line 20, in download_s3_file(bucket, ingest_path, output_path)
#      16 fs = s3fs.S3FileSystem(anon=True, asynchronous=False)
#      18 if fs.exists(f"{bucket}/{ingest_path}"):
#      19     # Download file, will throw FileNotFoundError if non existent
# ---> 20     fs.download(f"{bucket}/{ingest_path}", output_path)
#      21     print(f"✅ downloading {ingest_path} & saving to {output_path}")
#      22 else:
#
# File ~/.local/lib/python3.9/site-packages/fsspec/spec.py:1333, in AbstractFileSystem.download(self, rpath, lpath, recursive, **kwargs)
#    1331 def download(self, rpath, lpath, recursive=False, **kwargs):
#    1332     """Alias of `AbstractFileSystem.get`."""
# -> 1333     return self.get(rpath, lpath, recursive=recursive, **kwargs)
#
# File ~/.local/lib/python3.9/site-packages/fsspec/asyn.py:111, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     108 @functools.wraps(func)
#     109 def wrapper(*args, **kwargs):
#     110     self = obj or args[0]
# --> 111     return sync(self.loop, func, *args, **kwargs)
#
# File ~/.local/lib/python3.9/site-packages/fsspec/asyn.py:84, in sync(loop, func, timeout, *args, **kwargs)
#      81 asyncio.run_coroutine_threadsafe(_runner(event, coro, result, timeout), loop)
#      82 while True:
#      83     # this loops allows thread to get interrupted
# ---> 84     if event.wait(1):
#      85         break
#      86     if timeout is not None:
#
# File ~/miniconda3/lib/python3.9/threading.py:581, in Event.wait(self, timeout)
#     579 signaled = self._flag
#     580 if not signaled:
# --> 581     signaled = self._cond.wait(timeout)
#     582 return signaled
#
# File ~/miniconda3/lib/python3.9/threading.py:316, in Condition.wait(self, timeout)
#     314 else:
#     315     if timeout > 0:
# --> 316         gotit = waiter.acquire(True, timeout)
#     317     else:
#     318         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# # HRRR

# %%
main("hrrr", data_type_dict.get("hrrr"), init_date, init_time)
