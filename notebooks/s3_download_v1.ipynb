# %% [markdown]
# ## Questions I have
# - bucket
# - split_loc
# - fh_loc
# - fxx_max
# - z_fill
# - full file_list_len

# %%
import sys
import numpy as np
import s3fs
import argparse
from datetime import datetime, timedelta
import os.path
from pathlib import Path
import time
import glob

from boto3 import client
from botocore import UNSIGNED
from botocore.client import Config

# %% [markdown]
# # Functions

# %%
"""
 download_s3_file 
 downloads the nwp file 

 ARGS: 
 bucket: f string :: 
 ingest_path : fstring  :: file that has been downloaded 
 output_path : fstring :: where you want file stored 

 RETURNS: 

 """


def download_s3_file(bucket, ingest_path, output_path):
    fs = s3fs.S3FileSystem(anon=True, asynchronous=False)

    if fs.exists(f"{bucket}/{ingest_path}"):
        # Download file, will throw FileNotFoundError if non existent
        fs.download(f"{bucket}/{ingest_path}", output_path)
        print(f"✅ downloading {ingest_path} & saving to {output_path}")
    else:
        print(f"‼️ file not found {ingest_path}")


"""
list_s3_files 
returns a list of files that have been downloaded for nwp 

 ARGS: 
 bucket
 model : string :: the model to be downloaded 
 date : fstring :: year-month-day
 init_time : double :: 00
 data_type : string :: file format 

 RETURNS: 
 list :: the files that exist from dowload in a list 

 """


def list_s3_files(bucket, model, date, init_time, data_type):
    conn = client("s3", config=Config(signature_version=UNSIGNED))

    if model == "nam":
        prefix = f"{model}.{date}/"
    elif model == "gfs":
        prefix = f"{model}.{date}/{init_time}/atmos/"
    elif model == "hrrr":
        prefix = f"{model}.{date}/conus/"

    response = conn.list_objects_v2(
        Bucket=bucket, Prefix=f"{prefix}{model}.t{init_time}z.{data_type}"
    )
    files = response.get("Contents")
    if files:
        all_files = [file.get("Key") for file in files]
        existing_files_for_download = [
            file
            for file in all_files
            if f"t{init_time}z.{data_type}" in file
            and not file.endswith("idx")
            and not file.endswith("anl")
        ]
        existing_files_for_download.sort()
        return existing_files_for_download
    else:
        return []


"""
get_avail_files 

 ARGS: 
 s3_bucket
 model : string :: the model to be downloaded 
 year : string :: 0000
 month : string :: 00
 day : string  :: 00
 init_time : double :: 00
 data_type : string :: file format 
 split_loc: 
 fh_loc: 
 fxx_max: 
 zfill: 
 download_dir: fstring :: directory path where you want the  data to be downloaded 

 fname_out: string :: part of datapath name to be saved in your directory 

 fname_end: string :: part of datapath name
 full_filelist_len: 

 RETURNS: 
 the files that exist for dowload 

 """


def get_avail_files(
    s3_bucket,
    model,
    year,
    month,
    day,
    init_time,
    data_type,
    split_loc,
    fh_loc,
    fxx_max,
    zfill,
    download_dir,
    fname_out,
    fname_end,
    full_filelist_len,
):
    ii = 0
    len_files_for_download = [0]
    while True:
        files_for_download = list_s3_files(
            s3_bucket, model, f"{year}{month}{day}", init_time, data_type
        )
        files_for_download = [
            file
            for file in files_for_download
            if int(file.split(".")[split_loc][fh_loc:]) <= fxx_max
        ]
        print(files_for_download)
        len_files_for_download.append(len(files_for_download))
        for file in files_for_download:
            fxx = file.split(".")[split_loc][fh_loc:]
            if not os.path.isdir(download_dir):
                print("making directory: ", download_dir)
                Path(download_dir).mkdir(parents=True, exist_ok=True)
            # check to see if output_path is a directory. if not, create directory
            output_path = f"{download_dir}{fname_out}{str(fxx).zfill(zfill)}{fname_end}"
            if not os.path.exists(output_path):
                # if the file already exists, do not redownload
                download_s3_file(s3_bucket, file, output_path)
                # call the rest of the pipeline here, run_pipeline
                # running cleaning through the pipeline could be the "sleep" period
                print("FXX IS: ", fxx)
            else:
                print(f"file has already been downloaded: {output_path}")

        # STOP WHILE LOOP IF ALL DESIRED FILES HAVE BEEN DOWNLOADED ON OUR SIDE
        if os.path.isdir(download_dir):
            files_downloaded = glob.glob(f"{download_dir}{fname_out}*{fname_end}")
            num_files_downloaded = len(files_downloaded)
            print(num_files_downloaded)
            if num_files_downloaded >= full_filelist_len:
                print("exiting from while loop")
                break

        # if no additional files are available compared to last try but the full_filelist_len has not been reached yet...
        if len_files_for_download[-1] == len_files_for_download[-2]:
            ii += 1
            print("same number of available files as last try. ii=", ii)
            if (
                ii > 10
            ):  # stop waiting for additional file if we have tried 10 separate times
                print("waited too long for new file, exiting while loop")
                break

        # try again in 90 seconds
        print("sleep: ", datetime.now())
        time.sleep(90)

# %% [markdown]
# # Global Variables

# %%
# this is how you want the files to be input for each model
# second component is the file format
data_type_dict = {"gfs": "pgrb2.0p50", "nam": "awphys", "hrrr": "wrfsfc"}

# download request time
init_time = "00"
init_date = datetime(2022, 1, 2)
end_date = datetime(2022, 2, 1)

# %% [markdown]
# # Main

# %%
# main
def main(model, data_type, init_date, init_time):
    month = str(init_date.month).zfill(2)
    print("Month: ", month)
    year = init_date.year
    print("Year", year)
    day = str(init_date.day).zfill(2)

    # where you want the files to download
    download_dir = (
        f"/home/aevans/nwp_bias/data/model_data/{model.upper()}/{year}/{month}/"
    )
    print("Downloand_dir: ", download_dir)

    if model == "nam":
        s3_bucket = f"noaa-{model}-pds"
    else:
        s3_bucket = f"noaa-{model}-bdp-pds"

    if model == "nam":
        fxx_max = 84
        split_loc, fh_loc = -3, -2
        fname_out = f"nam_218_{year}{month}{day}_{init_time}00_"
        fname_end = ".grb2"
        zfill = 3
        full_filelist_len = len(
            np.arange(0, 37, 1).tolist() + np.arange(39, 85, 3).tolist()
        )
    elif model == "gfs":
        fxx_max = 96
        split_loc, fh_loc = -1, 1
        fname_out = f"gfs_4_{year}{month}{day}_{init_time}00_"
        fname_end = ".grb2"
        zfill = 3
        full_filelist_len = len(np.arange(0, 99, 3))
    elif model == "hrrr":
        fxx_max = 18
        split_loc, fh_loc = -2, -2
        fname_out = f"{year}{month}{day}_hrrr.t{init_time}z.wrfsfcf"
        fname_end = ".grib2"
        zfill = 2
        full_filelist_len = len(range(0, 19))

    get_avail_files(
        s3_bucket,
        model,
        year,
        month,
        day,
        init_time,
        data_type,
        split_loc,
        fh_loc,
        fxx_max,
        zfill,
        download_dir,
        fname_out,
        fname_end,
        full_filelist_len,
    )

    print(
        f"full download for {init_time}z initialization of the {model.upper()} complete!"
    )

# %% [markdown]
# # GFS

# %%
delta2 = timedelta(days=1)
while init_date < end_date:
    main("gfs", data_type_dict.get("gfs"), init_date, init_time)
    init_date += delta2
# Out:
# Month:  01
# Year 2022
# Downloand_dir:  /home/aevans/nwp_bias/data/model_data/GFS/2022/01/
# ['gfs.20220102/00/atmos/gfs.t00z.pgrb2.0p50.f000', 'gfs.20220102/00/atmos/gfs.t00z.pgrb2.0p50.f003', 'gfs.20220102/00/atmos/gfs.t00z.pgrb2.0p50.f006', 'gfs.20220102/00/atmos/gfs.t00z.pgrb2.0p50.f009', 'gfs.20220102/00/atmos/gfs.t00z.pgrb2.0p50.f012', 'gfs.20220102/00/atmos/gfs.t00z.pgrb2.0p50.f015', 'gfs.20220102/00/atmos/gfs.t00z.pgrb2.0p50.f018', 'gfs.20220102/00/atmos/gfs.t00z.pgrb2.0p50.f021', 'gfs.20220102/00/atmos/gfs.t00z.pgrb2.0p50.f024', 'gfs.20220102/00/atmos/gfs.t00z.pgrb2.0p50.f027', 'gfs.20220102/00/atmos/gfs.t00z.pgrb2.0p50.f030', 'gfs.20220102/00/atmos/gfs.t00z.pgrb2.0p50.f033', 'gfs.20220102/00/atmos/gfs.t00z.pgrb2.0p50.f036', 'gfs.20220102/00/atmos/gfs.t00z.pgrb2.0p50.f039', 'gfs.20220102/00/atmos/gfs.t00z.pgrb2.0p50.f042', 'gfs.20220102/00/atmos/gfs.t00z.pgrb2.0p50.f045', 'gfs.20220102/00/atmos/gfs.t00z.pgrb2.0p50.f048', 'gfs.20220102/00/atmos/gfs.t00z.pgrb2.0p50.
# ✅ downloading gfs.20220103/00/atmos/gfs.t00z.pgrb2.0p50.f075 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220103_0000_075.grb2
# FXX IS:  075
# ✅ downloading gfs.20220103/00/atmos/gfs.t00z.pgrb2.0p50.f078 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220103_0000_078.grb2
# FXX IS:  078
# ✅ downloading gfs.20220103/00/atmos/gfs.t00z.pgrb2.0p50.f081 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220103_0000_081.grb2
# FXX IS:  081
# ✅ downloading gfs.20220103/00/atmos/gfs.t00z.pgrb2.0p50.f084 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220103_0000_084.grb2
# FXX IS:  084
# ✅ downloading gfs.20220103/00/atmos/gfs.t00z.pgrb2.0p50.f087 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220103_0000_087.grb2
# FXX IS:  087
# ✅ downloading gfs.20220103/00/atmos/gfs.t00z.pgrb2.0p50.f090 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220103_0000_090.grb2
# FXX IS:  090
# ✅ downloading gfs.20220103/00/atmos/gfs.t00z.pgrb2.0p50.f093 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220103_0000_093.grb2
# FXX IS:  093
# ✅ downloading gfs.20220103/00/atmos/gfs.t00z.pgrb2.0p50.f096 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220103_0000_096.grb2
# FXX IS:  096
# 33
# exiting from while loop
# full download for 00z initialization of the GFS complete!
# Month:  01
# Year 2022
# Downloand_dir:  /home/aevans/nwp_bias/data/model_data/GFS/2022/01/
# ['gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f000', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f003', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f006', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f009', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f012', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f015', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f018', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f021', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f024', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f027', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f030', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f033', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f036', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f039', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f042', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f045', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f048', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f051', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f054', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f057', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f060', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f063', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f066', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f069', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f072', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f075', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f078', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f081', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f084', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f087', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f090', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f093', 'gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f096']
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f000 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_000.grb2
# FXX IS:  000
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f003 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_003.grb2
# FXX IS:  003
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f006 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_006.grb2
# FXX IS:  006
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f009 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_009.grb2
# FXX IS:  009
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f012 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_012.grb2
# FXX IS:  012
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f015 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_015.grb2
# FXX IS:  015
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f018 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_018.grb2
# FXX IS:  018
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f021 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_021.grb2
# FXX IS:  021
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f024 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_024.grb2
# FXX IS:  024
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f027 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_027.grb2
# FXX IS:  027
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f030 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_030.grb2
# FXX IS:  030
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f033 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_033.grb2
# FXX IS:  033
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f036 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_036.grb2
# FXX IS:  036
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f039 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_039.grb2
# FXX IS:  039
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f042 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_042.grb2
# FXX IS:  042
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f045 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_045.grb2
# FXX IS:  045
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f048 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_048.grb2
# FXX IS:  048
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f051 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_051.grb2
# FXX IS:  051
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f054 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_054.grb2
# FXX IS:  054
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f057 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_057.grb2
# FXX IS:  057
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f060 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_060.grb2
# FXX IS:  060
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f063 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_063.grb2
# FXX IS:  063
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f066 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_066.grb2
# FXX IS:  066
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f069 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_069.grb2
# FXX IS:  069
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f072 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_072.grb2
# FXX IS:  072
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f075 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_075.grb2
# FXX IS:  075
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f078 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_078.grb2
# FXX IS:  078
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f081 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_081.grb2
# FXX IS:  081
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f084 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_084.grb2
# FXX IS:  084
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f087 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_087.grb2
# FXX IS:  087
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f090 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_090.grb2
# FXX IS:  090
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f093 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_093.grb2
# FXX IS:  093
# ✅ downloading gfs.20220104/00/atmos/gfs.t00z.pgrb2.0p50.f096 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220104_0000_096.grb2
# FXX IS:  096
# 33
# exiting from while loop
# full download for 00z initialization of the GFS complete!
# Month:  01
# Year 2022
# Downloand_dir:  /home/aevans/nwp_bias/data/model_data/GFS/2022/01/
# ['gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f000', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f003', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f006', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f009', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f012', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f015', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f018', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f021', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f024', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f027', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f030', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f033', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f036', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f039', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f042', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f045', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f048', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f051', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f054', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f057', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f060', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f063', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f066', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f069', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f072', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f075', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f078', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f081', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f084', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f087', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f090', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f093', 'gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f096']
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f000 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_000.grb2
# FXX IS:  000
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f003 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_003.grb2
# FXX IS:  003
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f006 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_006.grb2
# FXX IS:  006
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f009 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_009.grb2
# FXX IS:  009
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f012 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_012.grb2
# FXX IS:  012
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f015 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_015.grb2
# FXX IS:  015
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f018 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_018.grb2
# FXX IS:  018
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f021 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_021.grb2
# FXX IS:  021
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f024 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_024.grb2
# FXX IS:  024
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f027 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_027.grb2
# FXX IS:  027
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f030 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_030.grb2
# FXX IS:  030
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f033 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_033.grb2
# FXX IS:  033
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f036 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_036.grb2
# FXX IS:  036
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f039 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_039.grb2
# FXX IS:  039
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f042 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_042.grb2
# FXX IS:  042
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f045 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_045.grb2
# FXX IS:  045
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f048 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_048.grb2
# FXX IS:  048
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f051 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_051.grb2
# FXX IS:  051
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f054 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_054.grb2
# FXX IS:  054
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f057 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_057.grb2
# FXX IS:  057
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f060 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_060.grb2
# FXX IS:  060
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f063 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_063.grb2
# FXX IS:  063
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f066 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_066.grb2
# FXX IS:  066
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f069 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_069.grb2
# FXX IS:  069
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f072 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_072.grb2
# FXX IS:  072
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f075 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_075.grb2
# FXX IS:  075
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f078 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_078.grb2
# FXX IS:  078
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f081 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_081.grb2
# FXX IS:  081
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f084 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_084.grb2
# FXX IS:  084
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f087 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_087.grb2
# FXX IS:  087
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f090 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_090.grb2
# FXX IS:  090
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f093 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_093.grb2
# FXX IS:  093
# ✅ downloading gfs.20220105/00/atmos/gfs.t00z.pgrb2.0p50.f096 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220105_0000_096.grb2
# FXX IS:  096
# 33
# exiting from while loop
# full download for 00z initialization of the GFS complete!
# Month:  01
# Year 2022
# Downloand_dir:  /home/aevans/nwp_bias/data/model_data/GFS/2022/01/
# ['gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f000', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f003', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f006', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f009', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f012', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f015', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f018', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f021', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f024', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f027', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f030', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f033', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f036', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f039', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f042', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f045', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f048', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f051', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f054', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f057', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f060', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f063', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f066', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f069', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f072', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f075', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f078', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f081', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f084', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f087', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f090', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f093', 'gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f096']
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f000 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_000.grb2
# FXX IS:  000
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f003 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_003.grb2
# FXX IS:  003
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f006 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_006.grb2
# FXX IS:  006
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f009 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_009.grb2
# FXX IS:  009
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f012 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_012.grb2
# FXX IS:  012
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f015 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_015.grb2
# FXX IS:  015
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f018 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_018.grb2
# FXX IS:  018
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f021 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_021.grb2
# FXX IS:  021
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f024 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_024.grb2
# FXX IS:  024
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f027 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_027.grb2
# FXX IS:  027
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f030 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_030.grb2
# FXX IS:  030
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f033 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_033.grb2
# FXX IS:  033
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f036 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_036.grb2
# FXX IS:  036
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f039 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_039.grb2
# FXX IS:  039
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f042 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_042.grb2
# FXX IS:  042
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f045 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_045.grb2
# FXX IS:  045
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f048 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_048.grb2
# FXX IS:  048
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f051 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_051.grb2
# FXX IS:  051
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f054 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_054.grb2
# FXX IS:  054
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f057 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_057.grb2
# FXX IS:  057
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f060 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_060.grb2
# FXX IS:  060
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f063 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_063.grb2
# FXX IS:  063
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f066 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_066.grb2
# FXX IS:  066
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f069 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_069.grb2
# FXX IS:  069
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f072 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_072.grb2
# FXX IS:  072
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f075 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_075.grb2
# FXX IS:  075
# ✅ downloading gfs.20220106/00/atmos/gfs.t00z.pgrb2.0p50.f078 & saving to /home/aevans/nwp_bias/data/model_data/GFS/2022/01/gfs_4_20220106_0000_078.grb2
# FXX IS:  078

# %% [markdown]
# # NAM

# %%
main("nam", data_type_dict.get("nam"), init_date, init_time)

# %% [markdown]
# # HRRR

# %%
main("hrrr", data_type_dict.get("hrrr"), init_date, init_time)
