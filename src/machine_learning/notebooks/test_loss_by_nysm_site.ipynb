# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
import numpy as np
import calendar
import time
from matplotlib import colors
from sklearn import preprocessing
import cartopy.crs as crs
import cartopy.feature as cfeature
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
test_loss = pd.read_csv(
    "/home/aevans/nwp_bias/src/machine_learning/data/shmaronshmevans_which_stations_can_learn_new_view_table_data (1).csv"
)

# %%
test_loss
# Out:
#                         Name     Tags  Server end time File name station  \
# 0          musical_dune_3007  learned    1701272860984   lstm.py    KIND
# 1          entitled_ape_6793  learned    1701268397157   lstm.py    BSPA
# 2         running_globe_2481  learned    1701274664247   lstm.py    PENN
# 3         lexical_light_5651  learned    1701271659624   lstm.py    GFLD
# 4    identical_scorpion_7154  learned    1701267285378   lstm.py    BELD
# 5       primary_transom_1116  learned    1701275764241   lstm.py    SCHA
# 6       amethyst_settee_5252  learned    1701269684174   lstm.py    COHO
# 7      identical_beetle_5733  learned    1701275371960   lstm.py    ROXB
# 8     standard_scaffold_5263  learned    1701274163439   lstm.py    OPPE
# 9     worthwhile_settee_1456  learned    1701269086553   lstm.py    CHES
# 10          lime_arcade_4397  learned    1701275564152   lstm.py    SARA
# 11      chronic_unicorn_3111  learned    1701270492644   lstm.py    DUAN
# 12    inherent_kangaroo_8022  learned    1701272462919   lstm.py    HFAL
# 13           key_terminal_62  learned    1701274862520   lstm.py    PISE
# 14         supreme_palm_4033  learned    1701267186385   lstm.py    BEAC
# 15  imaginative_penguin_9463  learned    1701269777978   lstm.py    COLD
# 16      ordinary_jigsaw_5316  learned    1701279396365   lstm.py    RAQU
# 17         immense_heron_424  learned    1701276288489   lstm.py    SOME
# 18             net_bear_8073  learned    1701270967797   lstm.py    ELLE
# 19        maximum_taper_6994  learned    1701272260327   lstm.py    HART
# 20      variable_louver_5744  learned    1701276386136   lstm.py    SOUT
# 21     financial_stable_3549  learned    1701271465699   lstm.py    GABR
# 22     indirect_thinner_9823  learned    1701268984962   lstm.py    CHAZ
# 23           nice_fjord_7940  learned    1701273162904   lstm.py    MALO
#
#     Duration  train_loss  test_loss  test_loss (Min)  Current epoch  \
# 0         73    0.158837   0.243957         0.238500             30
# 1         71    0.167517   0.243775         0.241351             30
# 2         68    0.185325   0.242266         0.241866             30
# 3         61    0.154200   0.243352         0.243352             30
# 4         68    0.219895   0.250940         0.248663             30
# 5         71    0.171092   0.249236         0.249236             30
# 6         67    0.167354   0.253174         0.250935             30
# 7         67    0.177588   0.261763         0.252748             30
# 8         70    0.191327   0.253598         0.253598             30
# 9         69    0.176626   0.272353         0.256793             30
# 10        63    0.107282   0.264134         0.264134             30
# 11        70    0.187336   0.267084         0.267084             30
# 12        69    0.180043   0.279196         0.268737             30
# 13        62    0.139313   0.294575         0.280550             30
# 14        69    0.217380   0.281196         0.281196             30
# 15        63    0.176760   0.286442         0.285924             30
# 16        61    0.155653   0.294538         0.294538             30
# 17        72    0.238110   0.295662         0.294639             30
# 18        59    0.127750   0.297455         0.294983             30
# 19        67    0.291719   0.300919         0.300919             30
# 20        65    0.203001   0.305544         0.305544             30
# 21        64    0.174152   0.315934         0.308733             30
# 22        63    0.136814   0.314907         0.314907             30
# 23        61    0.182591   0.359317         0.332652             30
#
#     forecast_lead  num_layers  sequence_length  Learning Rate  Batch size
# 0             0.0         5.0            120.0          0.005     10000.0
# 1             0.0         5.0            120.0          0.005     10000.0
# 2             0.0         5.0            120.0          0.005     10000.0
# 3             0.0         5.0            120.0          0.005     10000.0
# 4             0.0         5.0            120.0          0.005     10000.0
# 5             0.0         5.0            120.0          0.005     10000.0
# 6             0.0         5.0            120.0          0.005     10000.0
# 7             0.0         5.0            120.0          0.005     10000.0
# 8             0.0         5.0            120.0          0.005     10000.0
# 9             0.0         5.0            120.0          0.005     10000.0
# 10            0.0         5.0            120.0          0.005     10000.0
# 11            0.0         5.0            120.0          0.005     10000.0
# 12            0.0         5.0            120.0          0.005     10000.0
# 13            0.0         5.0            120.0          0.005     10000.0
# 14            0.0         5.0            120.0          0.005     10000.0
# 15            0.0         5.0            120.0          0.005     10000.0
# 16            0.0         5.0            120.0          0.005     10000.0
# 17            0.0         5.0            120.0          0.005     10000.0
# 18            0.0         5.0            120.0          0.005     10000.0
# 19            0.0         5.0            120.0          0.005     10000.0
# 20            0.0         5.0            120.0          0.005     10000.0
# 21            0.0         5.0            120.0          0.005     10000.0
# 22            0.0         5.0            120.0          0.005     10000.0
# 23            0.0         5.0            120.0          0.005     10000.0

# %%
projPC = crs.PlateCarree()
latN = 45.5
latS = 40
lonW = -80
lonE = -71.5
cLat = (latN + latS) / 2
cLon = (lonW + lonE) / 2
projLcc = crs.LambertConformal(central_longitude=cLon, central_latitude=cLat)

fig, ax = plt.subplots(figsize=(12, 9), subplot_kw={"projection": crs.PlateCarree()})
ax.set_extent([lonW, lonE, latS, latN], crs=projPC)
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle="--")
ax.add_feature(cfeature.LAKES, alpha=0.5)
ax.add_feature(cfeature.STATES)
ax.xticklabels_top = False
ax.ylabels_right = False
ax.gridlines(
    crs=crs.PlateCarree(),
    draw_labels=True,
    linewidth=2,
    color="black",
    alpha=0.5,
    linestyle="--",
)
plotter = ax.scatter(
    x=nysm_df["lon"],
    y=nysm_df["lat"],
    c="cyan",
    s=50,
    marker="o",
    edgecolor="black",
    transform=crs.PlateCarree(),
)
ax.set_title(f"New York State Mesonet", size=16)
ax.set_xlabel("Longitude", size=14)
ax.set_ylabel("Latitude", size=14)
ax.tick_params(axis="x", labelsize=12)
ax.tick_params(axis="y", labelsize=12)
ax.grid()
