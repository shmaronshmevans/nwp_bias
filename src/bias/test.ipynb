# %%
import xarray as xr
import matplotlib.pyplot as plt
import pandas as pd

# %%
ds = pd.read_parquet(
    "/home/aevans/ai2es/HRRR/cleanedHRRR/2018/01/20180101_hrrr.t00z_wrfsfc_fhAll.parquet"
)

# %%
ds
# Out:
#                                                t2m          pt      sh2  \
# time       y             x
# 2018-01-01 -5.910277e+05 -5.623610e+05  265.868561  275.170532  0.00191
#                          -5.593566e+05  265.993561  275.170532  0.00189
#                          -5.563521e+05  265.993561  275.108032  0.00186
#                          -5.533477e+05  265.993561  274.983032  0.00183
#                          -5.503432e+05  265.931061  274.858032  0.00180
# ...                                            ...         ...      ...
#             1.383248e+06  2.435715e+06  262.289734  261.494385  0.00099
#                           2.438718e+06  262.227234  261.556885  0.00101
#                           2.441721e+06  262.352234  261.619385  0.00102
#                           2.444724e+06  262.477234  261.681885  0.00102
#                           2.447727e+06  262.352234  261.681885  0.00102
#
#                                                d2m         r2       u10  \
# ...
