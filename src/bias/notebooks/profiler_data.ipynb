# %%
# %matplotlib inline
import pandas as pd
import xarray as xr
import glob
import numpy as np
import metpy.calc as mpcalc
from metpy.units import units

# %%
nysm_path = "/home/aevans/nysm/archive/profiler/netcdf/proc-range/2018/02/20180201.nc"
ds_nysm_month = xr.open_mfdataset(f"{nysm_path}")

# %%
ds_nysm_month
# Out:
# <xarray.Dataset> Size: 22MB
# Dimensions:                    (station: 17, time: 144, range: 173)
# Coordinates:
#   * station                    (station) <U9 612B 'PROF_ALBA' ... 'PROF_WEBS'
#   * time                       (time) datetime64[ns] 1kB 2018-02-01T00:05:00 ...
#   * range                      (range) int64 1kB 0 25 50 75 ... 9500 9750 10000
# Data variables: (12/27)
#     temperature                (station, time, range) float32 2MB dask.array<chunksize=(17, 144, 173), meta=np.ndarray>
#     temperature_qc             (station, time) float32 10kB dask.array<chunksize=(17, 144), meta=np.ndarray>
#     relative_humidity          (station, time, range) float32 2MB dask.array<chunksize=(17, 144, 173), meta=np.ndarray>
#     relative_humidity_qc       (station, time) float32 10kB dask.array<chunksize=(17, 144), meta=np.ndarray>
#     vapor_density              (station, time, range) float32 2MB dask.array<chunksize=(17, 144, 173), meta=np.ndarray>
# ...
